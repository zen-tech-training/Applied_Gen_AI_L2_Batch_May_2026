# %%
# Install necessary libraries
# !pip install -q langchain openai
# !pip install -q langchain openai langchain_openai

# %%
# Import necessary modules
import os
from langchain.prompts import PromptTemplate
from langchain_openai import OpenAI
from google.colab import userdata

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Define the prompt template
template = """
You are a helpful assistant that answers questions about {topic}.

Question: {question}
Answer:
"""

prompt = PromptTemplate(
    input_variables=["topic", "question"],
    template=template,
)

# Initialize the OpenAI model
llm = OpenAI(temperature=0)

# Format the prompt with specific values

formatted_prompt = prompt.format(topic="Cricket", question="Who is Ravi Shastri? and What roles in worked in?")


# Run the prompt through the model
response = llm.invoke(formatted_prompt)

# Print the response
print(response)
# Out:
# Ravi Shastri is a former Indian cricketer and current head coach of the Indian national cricket team. He played as an all-rounder for the Indian team from 1981 to 1992. After his retirement, he worked as a commentator and cricket analyst before being appointed as the head coach in 2017. He has also served as the director of the Indian cricket team and as a member of the ICC Cricket Committee.

# %%
topic = input("Enter the topic: ")
question = input("Enter the question: ")

formatted_prompt = prompt.format(topic=topic, question=question)

response = llm.invoke(formatted_prompt)

print(response)
# Out:
# Enter the topic: movies
# Enter the question: who is SRK
#
# SRK, also known as Shah Rukh Khan, is an Indian actor, film producer, and television personality. He is often referred to as the "King of Bollywood" and has appeared in over 80 films. He is one of the most popular and influential actors in Indian cinema.

# %%
# Chat Template Example Below

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from google.colab import userdata
import os

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Initialize the OpenAI model
llm = ChatOpenAI(temperature=0)


# ✅ Template with {topic} and {question}
chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant that answers questions about {topic}."),
        ("human", "{question}")
    ]
)


topic = input("Enter the topic: ")
question = input("Enter the question: ")

formatted_chat_prompt = chat_template.format_messages(topic=topic, question=question)

chat_response = llm.invoke(formatted_chat_prompt)

# Access the content attribute to get the response text
print(chat_response.content)
# Out:
# Enter the topic: medicines
# Enter the question: what is paracetamol
# Paracetamol, also known as acetaminophen, is a common over-the-counter medication used to relieve pain and reduce fever. It is often used to treat conditions such as headaches, muscle aches, arthritis, and colds. Paracetamol is generally considered safe when taken as directed, but it is important to follow the recommended dosage and not exceed the maximum daily limit to avoid potential side effects.

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from google.colab import userdata
import os

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Initialize the OpenAI model
llm = ChatOpenAI(temperature=0)


# ✅ Template with {topic} and {question}
chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant that answers questions about {topic}."),
        ("human", "{question}")
    ]
)


topic = input("Enter the topic: ")
question = input("Enter the question: ")

formatted_chat_prompt = chat_template.format_messages(topic=topic, question=question)

chat_response = llm.invoke(formatted_chat_prompt)

# Access the content attribute to get the response text
print(chat_response.content)
# Out:
# Enter the topic: movies
# Enter the question: who is SRK
# SRK is an abbreviation for Shah Rukh Khan, a famous Indian actor and film producer who is often referred to as the "King of Bollywood." He has appeared in numerous successful Bollywood films and is one of the most popular and influential actors in the Indian film industry.

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from google.colab import userdata
import os

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Initialize the ChatOpenAI model
llm = ChatOpenAI(temperature=0)

# Ask for the topic once
topic = input("Enter the topic: ")

# Loop to ask multiple questions
while True:
    question = input("\nEnter your question (or type 'exit' to quit): ")

    if question.lower() in ['exit', 'quit']:
        print("Exiting... Have a great day!")
        break

    # Format and send the prompt
    chat_template = ChatPromptTemplate.from_messages(
        [
            ("system", "You are a helpful assistant that answers questions about {topic}."),
            ("human", "{question}")
        ]
    )

    formatted_chat_prompt = chat_template.format_messages(topic=topic, question=question)
    chat_response = llm.invoke(formatted_chat_prompt)

    # Show the answer
    print("\nAnswer:", chat_response.content)
# Out:
# Enter the topic: cricket
#
# Enter your question (or type 'exit' to quit): who is SRT
#
# Answer: SRT stands for Sachin Ramesh Tendulkar, who is a former Indian cricketer widely regarded as one of the greatest batsmen in the history of cricket. He is also known as the "Master Blaster" and "Little Master." Tendulkar holds numerous records in international cricket and is considered a legend in the sport.
#
# Enter your question (or type 'exit' to quit): who scored first double hunder in ODIs
#
# Answer: The first double century in One Day Internationals (ODIs) was scored by Indian cricketer Sachin Tendulkar. He achieved this milestone on February 24, 2010, against South Africa in Gwalior, India. Sachin Tendulkar scored an unbeaten 200 runs in that match.
#
# Enter your question (or type 'exit' to quit): who has maximum double hundreds
#
# Answer: The cricketer with the most double centuries in Test cricket is Sir Don Bradman from Australia, who scored 12 double centuries in his career.
#
# Enter your question (or type 'exit' to quit): who has maximum double hundreds in ODIs
#
# Answer: As of now, there are only three players who have scored a double century in One Day Internationals (ODIs). They are:
#
# 1. Sachin Tendulkar (India) - 200* against South Africa in 2010
# 2. Virender Sehwag (India) - 219 against West Indies in 2011
# 3. Rohit Sharma (India) - 209 against Australia in 2013 and 264 against Sri Lanka in 2014
#
# So, Rohit Sharma holds the record for the most double centuries in ODIs with three to his name.
#
# Enter your question (or type 'exit' to quit): who has maximum ducks in ODIs
#
# Answer: The player with the most ducks in One Day Internationals (ODIs) is Sanath Jayasuriya from Sri Lanka, with a total of 34 ducks in his ODI career.
#
# Enter your question (or type 'exit' to quit): quit
# Exiting... Have a great day!

# %%
# multiple topics

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from google.colab import userdata
import os

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Initialize the ChatOpenAI model
llm = ChatOpenAI(temperature=0)

print("Welcome! You can ask questions on any topic.")
print("Type 'change topic' to switch topics or 'exit' to quit.\n")

# Master loop for multiple topics
run = True
while run:
    topic = input("Enter the topic you'd like to ask about: ")
    if topic.lower() in ['exit', 'quit']:
        print("Goodbye!")
        break

    # Inner loop for multiple questions under the same topic
    while True:
        question = input("\nAsk your question (or type 'change topic' or 'exit'): ").strip().lower()

        if question == 'exit' or question == 'quit':
            print("Goodbye!")
            run = False  # safely exit both loops
            break
        elif question == 'change topic':
            break

        # Chat prompt template
        chat_template = ChatPromptTemplate.from_messages(
            [
                ("system", "You are a helpful assistant that answers questions about {topic}."),
                ("human", "{question}")
            ]
        )

        formatted_chat_prompt = chat_template.format_messages(topic=topic, question=question)
        chat_response = llm.invoke(formatted_chat_prompt)

        print("\nAnswer:", chat_response.content)
# Out:
# Welcome! You can ask questions on any topic.
# Type 'change topic' to switch topics or 'exit' to quit.
#
# Enter the topic you'd like to ask about: cricket
#
# Ask your question (or type 'change topic' or 'exit'): who is SKY
#
# Answer: "Sky" could refer to Sky Sports, a popular sports television network that broadcasts cricket matches among other sports. Sky Sports is known for its extensive coverage of cricket events around the world.
#
# Ask your question (or type 'change topic' or 'exit'): who is called as SKY in indian cricket t20 team
#
# Answer: In the Indian cricket T20 team, Shikhar Dhawan is often referred to as "Gabbar" or "The One" rather than "Sky." "Sky" is a nickname for Shreyas Iyer, who is also a part of the Indian cricket team.
#
# Ask your question (or type 'change topic' or 'exit'): who is sehwag
#
# Answer: Virender Sehwag is a former Indian cricketer who is considered one of the most destructive batsmen in the history of the game. He was known for his aggressive style of play and his ability to score runs quickly. Sehwag played for the Indian national team from 1999 to 2013 and achieved many records during his career, including being the only Indian to score a triple century in Test cricket twice.
#
# Ask your question (or type 'change topic' or 'exit'): change topic
# Enter the topic you'd like to ask about: movies
#
# Ask your question (or type 'change topic' or 'exit'): who is SRK
#
# Answer: SRK is an abbreviation for Shah Rukh Khan, a famous Indian actor and film producer who is often referred to as the "King of Bollywood." He has appeared in numerous successful Bollywood films and is one of the most popular and influential actors in the Indian film industry.
#
# Ask your question (or type 'change topic' or 'exit'): quit
# Goodbye!

# %%
# Chat-bot with Gradio

# %%
# Below

# %%
# ✅ STEP 1: Install dependencies
# !pip install --quiet langchain openai gradio

# ✅ STEP 2: Imports
import gradio as gr
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# ✅ STEP 3: Setup OpenAI key securely
from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# ✅ STEP 4: Initialize OpenAI LLM
llm = ChatOpenAI(temperature=0)

# ✅ STEP 5: Define the chatbot function
def chatbot_fn(topic, question):
    prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a helpful assistant that answers questions about {topic}."),
        ("human", "{question}")
    ])
    messages = prompt.format_messages(topic=topic, question=question)
    response = llm.invoke(messages)
    return response.content

# ✅ STEP 6: Launch Gradio UI
with gr.Blocks() as demo:
    gr.Markdown("### 🤖 OpenAI Chatbot (LangChain + Gradio in Colab)")
    topic = gr.Textbox(label="Topic", placeholder="e.g. Healthcare, Cricket")
    question = gr.Textbox(label="Your Question", placeholder="Ask your question...")
    response = gr.Textbox(label="Response")
    ask_btn = gr.Button("Ask")
    ask_btn.click(fn=chatbot_fn, inputs=[topic, question], outputs=response)

demo.launch(share=True)  # use share=True to expose public link in Colab
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://746aa24c39cc628a20.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://746aa24c39cc628a20.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
