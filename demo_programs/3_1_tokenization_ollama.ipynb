# %%
import tiktoken

# %%
encoding = tiktoken.get_encoding('cl100k_base')
#text = 'I work in IT industry. I like mechanical industry'
text = 'Generative AI (Gen AI) is a branch of artificial intelligence focused on content creation'
tokens = encoding.encode(text)
print(tokens)
print(len(tokens))
print('Decoded text ', encoding.decode(tokens))

for token in tokens:
    print(f"Token ID: {token}, Input test: {encoding.decode([token])}")
# Out:
# [5648, 1413, 15592, 320, 10172, 15592, 8, 374, 264, 9046, 315, 21075, 11478, 10968, 389, 2262, 9886]
# 17
# Decoded text  Generative AI (Gen AI) is a branch of artificial intelligence focused on content creation
# Token ID: 5648, Input test: Gener
# Token ID: 1413, Input test: ative
# Token ID: 15592, Input test:  AI
# Token ID: 320, Input test:  (
# Token ID: 10172, Input test: Gen
# Token ID: 15592, Input test:  AI
# Token ID: 8, Input test: )
# Token ID: 374, Input test:  is
# Token ID: 264, Input test:  a
# Token ID: 9046, Input test:  branch
# Token ID: 315, Input test:  of
# Token ID: 21075, Input test:  artificial
# Token ID: 11478, Input test:  intelligence
# Token ID: 10968, Input test:  focused
# Token ID: 389, Input test:  on
# Token ID: 2262, Input test:  content
# Token ID: 9886, Input test:  creation
